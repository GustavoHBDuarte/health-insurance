# %% [markdown]
# # <font color="green"> Library Imports </font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import pickle
import matplotlib.pyplot as plt
from scikitplot.metrics import plot_cumulative_gain, plot_lift_curve

import psycopg2

from sqlalchemy import create_engine
from pycorrcat.pycorrcat         import plot_corr, corr_matrix

from imblearn.ensemble import BalancedRandomForestClassifier
from lightgbm import LGBMClassifier

from sklearn.model_selection     import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing       import MinMaxScaler, RobustScaler, LabelEncoder, OrdinalEncoder
from sklearn.ensemble            import RandomForestClassifier, ExtraTreesClassifier
from sklearn.dummy               import DummyClassifier
from sklearn.metrics             import plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve
from sklearn.metrics             import accuracy_score, balanced_accuracy_score, roc_curve, auc, precision_score, f1_score, recall_score, classification_report, plot_confusion_matrix
from sklearn.linear_model        import LogisticRegression
from sklearn.neighbors           import KNeighborsClassifier

from autofeat import AutoFeatClassifier, FeatureSelector

import xgboost                   as xgb

import scipy.stats               as stats

from boruta                      import BorutaPy

import warnings

# %% [markdown]
# # <font color="green"> Helper functions </font>

# %%
def descriptive_statistics(df):
    
    df = df.select_dtypes(include=['int64', 'float64'])

    # Descriptive statistics

    df_descriptive = pd.DataFrame(data=[df.apply(np.min),
                                        df.apply(np.max),
                                        df.apply(lambda x: np.max(x) - np.min(x)),
                                        df.apply(np.mean),
                                        df.apply(np.median),
                                        df.apply(np.std),
                                        df.apply(lambda x: x.skew()),
                                        df.apply(lambda x: x.kurtosis())],
                                  index=np.array(['min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']))
    
    return df_descriptive



def get_model_metrics(model_name, model, X_train, y_train, X_test, y_test):
    
    

    inst_model = model.fit(X_train, y_train)


    y_pred = inst_model.predict(X_test)


    # Metrics:



    # Accuracy

    print('Accuracy: {}\n'.format(round(accuracy_score(y_test, y_pred),3)))


    # Balanced Accuracy

    print('Balanced Accuracy: {}\n'.format(round(balanced_accuracy_score(y_test, y_pred),3)))


    # AUC ROC


    # fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=1) <- sintax

    fpr, tpr, thresholds = roc_curve(y_test,
                                     np.array([i[1] for i in inst_model.predict_proba(X_test)]), 
                                     pos_label=1)

    auc(fpr, tpr)

    print('AUC-ROC: {}\n'.format(round(auc(fpr, tpr),3)))


    # Classification report

    print('Classification report:\n\n {}\n'.format(classification_report(y_test, y_pred)))


    # Gathering metrics for this estimator

    inst_model_accuracy = accuracy_score(y_test, y_pred)

    inst_model_bal_accuracy = balanced_accuracy_score(y_test, y_pred)

    inst_model_auc = auc(fpr, tpr)

    inst_model_precision = precision_score(y_test, y_pred)

    inst_model_f1 = f1_score(y_test, y_pred)

    inst_model_recall = recall_score(y_test, y_pred)
    
    
    
    # Getting df
    
    
    df = pd.DataFrame(data=[model_name, inst_model_accuracy,
                            inst_model_bal_accuracy, 
                            inst_model_auc, 
                            inst_model_precision, 
                            inst_model_f1, 
                            inst_model_recall]).transpose()

    df.columns = ['Model name', 'Accuracy', 'Balanced Accuracy', 'AUC', 'Precision', 'F1-score', 'Recall']
    
    return df  



def precision_at_k(X_test, y_test, pred_proba_model, k=1000):
    
    df_temp = pd.DataFrame()

    df_temp['id'] = X_test.index # setting id as column

    df_temp['response'] = y_test.tolist() # retrieving 'response' column
    
    df_temp['score'] = pred_proba_model[:,1].tolist() # creating 'score' column
    
    df_temp = df_temp[['id', 'score', 'response']]
    
    df_temp = df_temp.sort_values('score', ascending=False) # sorting by score
    
    df_temp['k'] = range(1, len(df_temp)+1) # creating 'k' column
    
    df_temp['precision_at_k'] = df_temp['response'].cumsum() / df_temp['k'] # calculating precision at k for each row
    
    return df_temp.loc[df_temp['k']==k, 'precision_at_k'].values[0] # selecting precision at k



def recall_at_k(X_test, y_test, pred_proba_model, k=1000):
    
    df_temp = pd.DataFrame()

    df_temp['id'] = X_test.index # setting id as column

    df_temp['response'] = y_test.tolist() # retrieving 'response' column
    
    df_temp['score'] = pred_proba_model[:,1].tolist() # creating 'score' column
    
    df_temp = df_temp[['id', 'score', 'response']]
    
    df_temp = df_temp.sort_values('score', ascending=False) # sorting by score
    
    df_temp['k'] = range(1, len(df_temp)+1) # creating 'k' column
    
    df_temp['recall_at_k'] = df_temp['response'].cumsum() / df_temp['response'].sum() # calculating recall at k for each row
    
    return df_temp.loc[df_temp['k']==k, 'recall_at_k'].values[0] # selecting precision at k



def jupyter_settings():
    
    pd.options.display.max_columns = None   
    


warnings.filterwarnings("ignore")
jupyter_settings()

# %% [markdown]
# # 1.0 Data import and basic inspection

# %% [markdown]
# ## <font color="gray"> 1.1 Data loading and checking </font>

# %%
# Data loading

## Importing db credentials

db_credentials = pd.read_csv('/mnt/d/Gustavo/health-insurance/db_credentials.txt', header=None)

host = db_credentials[0][0]

port = db_credentials[1][0]

database = db_credentials[2][0]

user = db_credentials[3][0]

psw = db_credentials[4][0]

# %%
# Schema

## Checking DB schema where tables belong to


# connecting Postgres
connection = psycopg2.connect('postgresql://{}:{}@{}:{}/{}'.format(user, psw, host, port, database))

# cursor object
cursor= connection.cursor()


# nspname: name of the namespace
#pg_namespace: contains schema definitions

query_schema = """

    SELECT nspname
    FROM pg_catalog.pg_namespace
    
"""

cursor.execute(query_schema)

record = (cursor.fetchall())

print(record)

cursor.close()

connection.close()
# Out:
# [('pg_toast',), ('pg_temp_1',), ('pg_toast_temp_1',), ('pg_catalog',), ('information_schema',), ('public',), ('pa004',), ('pg_temp_4',), ('pg_toast_temp_4',), ('pa005',), ('pg_temp_9',), ('pg_toast_temp_9',)]

# %%
# Selecting data from database - SQL query ('insurance' table - pa004 schema)

query = """
    SELECT *
    FROM pa004.insurance

"""

# Connecting to Postgres database

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, psw, host, port, database))


# executing sql query

df_insurance = pd.read_sql_query(query, con=engine)

# closing database connection

engine.dispose()

# %%
# Selecting data from database - SQL query ('users' table - pa004 schema)

query = """
    SELECT *
    FROM pa004.users

"""

# Connecting to Postgres database

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, psw, host, port, database))


# executing sql query

df_users = pd.read_sql_query(query, con=engine)

# closing database connection

engine.dispose()

# %%
# Selecting data from database - SQL query ('vehicle' table - pa004 schema)

query = """
    SELECT *
    FROM pa004.vehicle

"""

# Connecting to Postgres database

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, psw, host, port, database))


# executing sql query

df_vehicle = pd.read_sql_query(query, con=engine)

# closing database connection

engine.dispose()

# %%
# Checking tables

df_insurance.head()
# Out:
#    id  previously_insured  annual_premium  vintage  response
# 0   1                   0         40454.0      217         1
# 1   2                   0         33536.0      183         0
# 2   3                   0         38294.0       27         1
# 3   4                   1         28619.0      203         0
# 4   5                   1         27496.0       39         0

# %%
df_users.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel
# 0   1    Male   44         28.0                  26.0
# 1   2    Male   76          3.0                  26.0
# 2   3    Male   47         28.0                  26.0
# 3   4    Male   21         11.0                 152.0
# 4   5  Female   29         41.0                 152.0

# %%
df_vehicle.head()
# Out:
#    id  driving_license vehicle_age vehicle_damage
# 0   1                1   > 2 Years            Yes
# 1   2                1    1-2 Year             No
# 2   3                1   > 2 Years            Yes
# 3   4                1    < 1 Year             No
# 4   5                1    < 1 Year             No

# %%
# Merging tables

## merging df_users with df_insurance
df = pd.merge(left=df_users, right=df_insurance, how='left', on='id')

# resulting df with df_vehicle
df = pd.merge(left=df, right=df_vehicle, how='left', on='id')

df
# Out:
#             id  gender  age  region_code  policy_sales_channel  \
# 0            1    Male   44         28.0                  26.0
# 1            2    Male   76          3.0                  26.0
# 2            3    Male   47         28.0                  26.0
# 3            4    Male   21         11.0                 152.0
# 4            5  Female   29         41.0                 152.0
# ...        ...     ...  ...          ...                   ...
# 381104  381105    Male   74         26.0                  26.0
# 381105  381106    Male   30         37.0                 152.0
# 381106  381107    Male   21         30.0                 160.0
# 381107  381108  Female   68         14.0                 124.0
# 381108  381109    Male   46         29.0                  26.0
#
#         previously_insured  annual_premium  vintage  response  \
# 0                        0         40454.0      217         1
# 1                        0         33536.0      183         0
# ...

# %%
# Reorganizing columns

df = df[['id', 'gender', 'age', 'region_code', 'policy_sales_channel',
         'previously_insured', 'annual_premium', 'vintage',
         'driving_license', 'vehicle_age', 'vehicle_damage', 'response']]

# %%
# Data dimensions

print('Number of rows: {}'.format(df.shape[0]))
print('Number of columns: {}'.format(df.shape[1]))
# Out:
# Number of rows: 381109
# Number of columns: 12

# %%
# checking data types

df.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# region_code             float64
# policy_sales_channel    float64
# previously_insured        int64
# annual_premium          float64
# vintage                   int64
# driving_license           int64
# vehicle_age              object
# vehicle_damage           object
# response                  int64
# dtype: object

# %%
# Checking data info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   gender                381109 non-null  object
#  2   age                   381109 non-null  int64
#  3   region_code           381109 non-null  float64
#  4   policy_sales_channel  381109 non-null  float64
#  5   previously_insured    381109 non-null  int64
#  6   annual_premium        381109 non-null  float64
#  7   vintage               381109 non-null  int64
#  8   driving_license       381109 non-null  int64
#  9   vehicle_age           381109 non-null  object
#  10  vehicle_damage        381109 non-null  object
#  11  response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 37.8+ MB

# %%
# Checking for NA's

df.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# region_code             0
# policy_sales_channel    0
# previously_insured      0
# annual_premium          0
# vintage                 0
# driving_license         0
# vehicle_age             0
# vehicle_damage          0
# response                0
# dtype: int64

# %%
# Checking for duplicate rows

df.duplicated().sum()
# Out:
# 0

# %%
# Response variable

df['response'].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: response, dtype: int64

# %%
# Response variable - percentage

print('Percentage of people that did not purchase health insurance: {:.2f}'.format(df['response'].value_counts(normalize=True)[0]))
print('Percentage of people that purchased health insurance: {:.2f}'.format(df['response'].value_counts(normalize=True)[1]))
# Out:
# Percentage of people that did not purchase health insurance: 0.88
# Percentage of people that purchased health insurance: 0.12

# %%
# Setting 'id' column as index

df = df.set_index('id')

df
# Out:
#         gender  age  region_code  policy_sales_channel  previously_insured  \
# id
# 1         Male   44         28.0                  26.0                   0
# 2         Male   76          3.0                  26.0                   0
# 3         Male   47         28.0                  26.0                   0
# 4         Male   21         11.0                 152.0                   1
# 5       Female   29         41.0                 152.0                   1
# ...        ...  ...          ...                   ...                 ...
# 381105    Male   74         26.0                  26.0                   1
# 381106    Male   30         37.0                 152.0                   1
# 381107    Male   21         30.0                 160.0                   1
# 381108  Female   68         14.0                 124.0                   0
# 381109    Male   46         29.0                  26.0                   0
#
# ...

# %%
# Adjusting data types

df[['region_code',
    'policy_sales_channel',
    'annual_premium']] = df[['region_code',
                             'policy_sales_channel',
                             'annual_premium']].astype('int')

# %% [markdown]
# ## <font color="gray"> 1.2 Descriptive statistics </font>

# %% [markdown]
# ### <i>1.2.1 descriptive statistics</i>

# %%
# Numerical and categorical attributes

# numerical attributes
num_attributes = df.select_dtypes(['int64', 'float64'])

# categorical attributes
cat_attributes = df.select_dtypes(exclude=['int64', 'float64'])

# %%
# Descriptive statistics

descriptive_statistics(df)
# Out:
#                 age  region_code  policy_sales_channel  previously_insured  \
# min       20.000000     0.000000              1.000000            0.000000
# max       85.000000    52.000000            163.000000            1.000000
# range     65.000000    52.000000            162.000000            1.000000
# mean      38.822584    26.388807            112.034295            0.458210
# median    36.000000    28.000000            133.000000            0.000000
# std       15.511591    13.229871             54.203924            0.498251
# skew       0.672539    -0.115266             -0.900008            0.167747
# kurtosis  -0.565655    -0.867857             -0.970810           -1.971871
#
#           annual_premium     vintage  driving_license  response
# min          2630.000000   10.000000         0.000000  0.000000
# max        540165.000000  299.000000         1.000000  1.000000
# range      537535.000000  289.000000         1.000000  1.000000
# ...

# %% [markdown]
# ### <i>1.2.2 general view of attributes</i>

# %%
# Numeric attributes view

# Exploring numerical attributes

# as we are interested in people who have purchased health insurance, in this evaluation we are going
# to filter the dataset based on this condition to see the behaviour of numerical attributes for this group

# we are not showing here the distribution for the numerical variable 'response' because it is our target variable

num_attributes.loc[num_attributes['response']==1, num_attributes.columns!='response'].hist(figsize=(20,15), color='gray');

# %%
# Now let's compare the distributions for the same variables with people who did not purchase
## health insurance

num_attributes.loc[num_attributes['response']==0, num_attributes.columns!='response'].hist(figsize=(20,15), color='red');

# %% [markdown]
# * It looks like there are some differences between the two evaluated groups when looking closely at some variables like age, policy sales channel and previously insured.
# * Probably for the features where there are obvious differences this are going to help the machine learning model to figure out whether the customer is going to purchase a health insurance or not (or the % probability of doing so).

# %%
# Categorical attributes view


plt.figure(figsize=(15,5))

# gender profile for people who have purchased health insurance

plt.subplot(1,2,1)
sns.barplot(x='gender',
            y=0,
            data=df.loc[df['response']==1, ['gender']].groupby('gender').size().reset_index())

plt.ylabel('Count')
plt.title('people who have purchased health insurance')


# gender profile for people who have not purchased health insurance

plt.subplot(1,2,2)
sns.barplot(x='gender',
            y=0,
            data=df.loc[df['response']==0, ['gender']].groupby('gender').size().reset_index())

plt.ylabel('Count')
plt.title('people who have NOT purchased health insurance')

plt.tight_layout();

# %% [markdown]
# The female/male distribution between people who have and have not purchased health insurance is quite similar although there is a slight difference between them

# %%
plt.figure(figsize=(15,5))

# vehicle_age profile for people who have purchased health insurance

plt.subplot(1,2,1)
sns.barplot(x='vehicle_age',
            y=0,
            data=df.loc[df['response']==1, ['vehicle_age']].groupby('vehicle_age').size().reset_index())

plt.ylabel('Count')
plt.title('people who have purchased health insurance')


# vehicle_age profile for people who have not purchased health insurance

plt.subplot(1,2,2)
sns.barplot(x='vehicle_age',
            y=0,
            data=df.loc[df['response']==0, ['vehicle_age']].groupby('vehicle_age').size().reset_index())

plt.ylabel('Count')
plt.title('people who have NOT purchased health insurance')

plt.tight_layout();

# %% [markdown]
# for people who have purchased health insurance most of their vehicle is aged between 1-2 year while for the people who have not purchased health unsurance the ratio between 1-2 year and <1 year is almost the same. Vehicle age seems to be a good variable to tell us wheter a certain person will or will not purchase health insurance.

# %%
plt.figure(figsize=(15,5))

# vehicle_damage profile for people who have purchased health insurance

plt.subplot(1,2,1)
sns.barplot(x='vehicle_damage',
            y=0,
            data=df.loc[df['response']==1, ['vehicle_damage']].groupby('vehicle_damage').size().reset_index())

plt.ylabel('Count')
plt.title('people who have purchased health insurance')


# vehicle_damage profile for people who have not purchased health insurance

plt.subplot(1,2,2)
sns.barplot(x='vehicle_damage',
            y=0,
            data=df.loc[df['response']==0, ['vehicle_damage']].groupby('vehicle_damage').size().reset_index())

plt.ylabel('Count')
plt.title('people who have NOT purchased health insurance')

plt.tight_layout();

# %% [markdown]
# When it comes to vehicle damage it is easy to see that for people who have purchased health insurance most of them had their vehicle previously damage (no brainer!), while for the people who have not most of them did not have their vehicle damaged. Also the observed No/Yes ratio is completely different between these 2 groups.

# %% [markdown]
# # 2.0 Feature engineering

# %%
df_2 = df.copy()

# %% [markdown]
# ## <font color="gray"> 2.1 Creating new features </font>

# %%
# Creating the feature 'stage of life'

df_2['stage_of_life']= df['age'].apply(lambda x: 'adult' if x>=20 and x<=39
                                       else 'middle_age_adult' if x>=40 and x<=59
                                       else 'senior_adult')

# %%
df_2.head()
# Out:
#     gender  age  region_code  policy_sales_channel  previously_insured  \
# id
# 1     Male   44           28                    26                   0
# 2     Male   76            3                    26                   0
# 3     Male   47           28                    26                   0
# 4     Male   21           11                   152                   1
# 5   Female   29           41                   152                   1
#
#     annual_premium  vintage  driving_license vehicle_age vehicle_damage  \
# id
# 1            40454      217                1   > 2 Years            Yes
# 2            33536      183                1    1-2 Year             No
# 3            38294       27                1   > 2 Years            Yes
# 4            28619      203                1    < 1 Year             No
# 5            27496       39                1    < 1 Year             No
#
#     response     stage_of_life
# id
# 1          1  middle_age_adult
# ...

# %% [markdown]
# ## <font color="gray"> 2.2 Hypothesis to be validated </font>

# %% [markdown]
# # 3.0 Data filtering

# %%
df_3 = df_2.copy()

# %%
# According to previous data visualization previously carried out (session 1.2.2) the feature 'vintage' seems to be
## constant and therefore do not carry useful information for group segregation. We are going to remove it

df_3 = df_3.drop(columns=['vintage'])

# %% [markdown]
# # 4.0 Exploratory Data Analysis (EDA)

# %%
df_4 = df_3.copy()

# %% [markdown]
# ## <font color="gray"> 4.1 Univariate analysis </font>

# %%
# Response variable

sns.countplot(df['response'])
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %% [markdown]
# ### <i>4.1.1 numerical attributes</i>

# %%
df_4.select_dtypes(['float64', 'int64']).hist(figsize=(15,10), bins=50);
plt.tight_layout()

# %% [markdown]
# ### <i>4.1.2 categorical attributes</i>

# %%
# sets plot size
plt.figure(figsize=(25, 50))

# sets the inital plot position
n = 1

# iterates over the columns to plot
for i in cat_attributes.columns:
    plt.subplot(5, 3, n)
    _ = sns.countplot(y=cat_attributes[i], orient='v')
    n += 1

# adjust height and wdith reserved for space between subplots  
plt.subplots_adjust(hspace=0.8)
plt.subplots_adjust(wspace=0.3)

# # display the plot
plt.show()

# %% [markdown]
# ## <font color="gray"> 4.2 Bivariate analysis </font>

# %% [markdown]
# ### <i>4.2.1 validating hypothesis raised</i>

# %% [markdown]
# ### <i>4.2.2 statistical hypothesis testing</i>

# %% [markdown]
# It will be applied to numeric continuous attributes:
#
# 'age', 'region_code', 'policy_sales_channel', 'annual_premium'
#
#
# But first let's test to check if the data distribution of these features has a gaussian shape (parametric distribution) so we can further apply the correct statistical test.

# %%
# Shapiro test

for i in ['age', 'region_code', 'policy_sales_channel', 'annual_premium']:

  stat, p = stats.shapiro(df_4.loc[:, i])
  
  print('Feature: {}'.format(i))
  print('stat=%.3f, p=%.3f' % (stat, p))

  if p > 0.05:
    print('Probably Gaussian\n')

  else:
    print('Probably not Gaussian\n')
# Out:
# Feature: age
# stat=0.911, p=0.000
# Probably not Gaussian
#
# Feature: region_code
# stat=0.942, p=0.000
# Probably not Gaussian
#
# Feature: policy_sales_channel
# stat=0.720, p=0.000
# Probably not Gaussian
#
# Feature: annual_premium
# stat=0.873, p=0.000
# Probably not Gaussian

# %% [markdown]
# Since these features probably have a not Gaussian shape we will apply Mann-Whitney non-parametric test:

# %%
for i in ['age', 'annual_premium']:

  stat, p = stats.mannwhitneyu(df_4.loc[df_4['response']==0, i], 
                               df_4.loc[df_4['response']==1, i])
  
  print('Feature: {}'.format(i))
  print('stat=%.3f, p=%.3f' % (stat, p))

  if p > 0.05:
    print('Probably the same distribution\n')

  else:
    print('Probably different distributions\n')
# Out:
# Feature: age
# stat=5826171170.500, p=0.000
# Probably different distributions
#
# Feature: annual_premium
# stat=7343668645.500, p=0.000
# Probably different distributions

# %%
# Age

sns.boxplot(x='response', y='age', data=df_4)
# Out:
# <AxesSubplot:xlabel='response', ylabel='age'>

# %%
# annual_premium

sns.boxplot(x='response', y='annual_premium', data=df_4)
# Out:
# <AxesSubplot:xlabel='response', ylabel='annual_premium'>

# %% [markdown]
# ## <font color="gray"> 4.3 Multivariate analysis </font>

# %% [markdown]
# ### <i>4.3.1 numerical attributes</i>

# %%
# Correlation analysis

plt.figure(figsize=(15,10))

sns.heatmap(df_4.select_dtypes(include=['float64', 'int64']).corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <i>4.3.2 categorical attributes</i>

# %%
# Correlation analysis

plt.figure(figsize=(15,10))

plot_corr(df_4,
          df_4.select_dtypes(exclude=['float64', 'int64']).columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0 Data preparation

# %%
df_5 = df_4.copy()

# %% [markdown]
# ## <font color="gray"> 5.1 Train/Test split </font>

# %%
# Train/Test split

# X_train, X_test, y_train, y_test = train_test_split(y, X, test_size=0.33, random_state=42) <- sintax

y_train, y_test, X_train, X_test = train_test_split(df_5['response'], 
                                                    df_5.drop(columns=['response']), 
                                                    test_size=0.33, 
                                                    random_state=42,
                                                    stratify=df_5['response'])

# %%
# Checking class proportion - Training set

y_train.value_counts(normalize=True)
# Out:
# 0    0.877435
# 1    0.122565
# Name: response, dtype: float64

# %%
# Checking class proportion - Testing set

y_test.value_counts(normalize=True)
# Out:
# 0    0.877439
# 1    0.122561
# Name: response, dtype: float64

# %%
# Reminding class proportion - Original data

df['response'].value_counts(normalize=True)
# Out:
# 0    0.877437
# 1    0.122563
# Name: response, dtype: float64

# %% [markdown]
# ## <font color="gray"> 5.2 Scaling - numerical attributes </font>

# %%
# Scaling age

scaler = MinMaxScaler()

scaler.fit(X_train[['age']].values)

X_train['age'] = scaler.transform(X_train[['age']].values) # scaling train
X_test['age'] = scaler.transform(X_test[['age']].values) # scaling test


# Scaling region_code

scaler = MinMaxScaler()

scaler.fit(X_train[['region_code']].values)

X_train['region_code'] = scaler.transform(X_train[['region_code']].values) # scaling train
X_test['region_code'] = scaler.transform(X_test[['region_code']].values) # scaling test


# Scaling policy_sales_channel

scaler = MinMaxScaler()

scaler.fit(X_train[['policy_sales_channel']].values)

X_train['policy_sales_channel'] = scaler.transform(X_train[['policy_sales_channel']].values) # scaling train
X_test['policy_sales_channel'] = scaler.transform(X_test[['policy_sales_channel']].values) # scaling test


# Scaling annual_premium

scaler = RobustScaler()

scaler.fit(X_train[['annual_premium']].values)

X_train['annual_premium'] = scaler.transform(X_train[['annual_premium']].values) # scaling train
X_test['annual_premium'] = scaler.transform(X_test[['annual_premium']].values) # scaling test

# %%
# Checking transformed features

X_train.select_dtypes(include=['float64', 'int64']).head()
# Out:
#              age  region_code  policy_sales_channel  previously_insured  \
# id
# 347089  0.153846     0.673077              0.932099                   1
# 148668  0.061538     0.192308              0.932099                   1
# 282683  0.630769     0.538462              0.154321                   0
# 101296  0.030769     0.115385              0.932099                   1
# 60279   0.046154     0.288462              0.932099                   0
#
#         annual_premium  driving_license
# id
# 347089       -0.153391                1
# 148668       -0.247924                1
# 282683        0.635488                1
# 101296        0.440577                1
# 60279         0.333754                1

# %% [markdown]
# ## <font color="gray"> 5.3 Encoding - categorical attributes </font>

# %%
X_train.select_dtypes(exclude=['float64', 'int64'])
# Out:
#         gender vehicle_age vehicle_damage     stage_of_life
# id
# 347089  Female    < 1 Year             No             adult
# 148668  Female    < 1 Year             No             adult
# 282683  Female    1-2 Year            Yes      senior_adult
# 101296    Male    < 1 Year             No             adult
# 60279   Female    < 1 Year             No             adult
# ...        ...         ...            ...               ...
# 378817    Male    < 1 Year            Yes             adult
# 361829    Male    < 1 Year             No             adult
# 91745     Male    < 1 Year             No             adult
# 48701   Female    1-2 Year             No  middle_age_adult
# 221792    Male    < 1 Year            Yes             adult
#
# [255343 rows x 4 columns]

# %%
# gender and vehicle_damage - One-hot encoding

X_train = pd.get_dummies(data=X_train, columns=['gender']) # encoding train
X_test = pd.get_dummies(data=X_test, columns=['gender']) # encoding test


# vehicle_damage - 1 for Yes, 0 for No

X_train['vehicle_damage'] = [1 if i=='Yes' else 0 for i in X_train['vehicle_damage']] # encoding train
X_test['vehicle_damage'] = [1 if i=='Yes' else 0 for i in X_test['vehicle_damage']] # encoding test


# vehicle_age - Ordinal encoding

encoder = OrdinalEncoder()

encoder.fit(X_train[['vehicle_age']].values)

X_train['vehicle_age'] = encoder.transform(X_train[['vehicle_age']].values) # encoding train
X_test['vehicle_age'] = encoder.transform(X_test[['vehicle_age']].values) # encoding test


# stage of life - Label encoding

encoder = LabelEncoder()

encoder.fit(X_train[['stage_of_life']].values)

X_train['stage_of_life'] = encoder.transform(X_train[['stage_of_life']].values) # encoding train
X_test['stage_of_life'] = encoder.transform(X_test[['stage_of_life']].values) # encoding test

# %% [markdown]
# # 6.0 Feature engineering/selection - AutoFeat

# %%
# X_train

X_train_1 = X_train.copy()


# y_train

y_train_1 = y_train.copy()

# %%
X_train.head()
# Out:
#              age  region_code  policy_sales_channel  previously_insured  \
# id
# 347089  0.153846     0.673077              0.932099                   1
# 148668  0.061538     0.192308              0.932099                   1
# 282683  0.630769     0.538462              0.154321                   0
# 101296  0.030769     0.115385              0.932099                   1
# 60279   0.046154     0.288462              0.932099                   0
#
#         annual_premium  driving_license  vehicle_age  vehicle_damage  \
# id
# 347089       -0.153391                1          1.0               0
# 148668       -0.247924                1          1.0               0
# 282683        0.635488                1          0.0               1
# 101296        0.440577                1          1.0               0
# 60279         0.333754                1          1.0               0
#
#         stage_of_life  gender_Female  gender_Male
# id
# 347089              0              1            0
# ...

# %% [markdown]
# ## <font color="gray"> 6.1 Autofeat feature engineering </font>

# %%
## feature engineering using AutoFeat
#
#model = AutoFeatClassifier(n_jobs=-1, feateng_steps=2)
#
#df = model.fit_transform(X_train_1, y_train)

# %%
# Saving model object (feature engineer) as pickle file

#pickle.dump(model, open('/mnt/d/Gustavo/Rosu/feature_engineer_health_insurance.pkl', 'wb')) # saving feature engineering object

# %%
# Loading model object (feature engineer) pickle file

model = pickle.load(open('/mnt/d/Gustavo/Rosu/feature_engineer_health_insurance.pkl', 'rb'))

# %%
df = model.transform(X_train_1)

# %%
model.score(df,y_train)
# Out:
# 0.690048287989097

# %%
X = df.copy()

# %%
X.columns
# Out:
# Index(['age', 'region_code', 'policy_sales_channel', 'previously_insured',
#        'annual_premium', 'driving_license', 'vehicle_age', 'vehicle_damage',
#        'stage_of_life', 'gender_Female', 'gender_Male', 'age*gender_Male',
#        'age*vehicle_age**3', 'age**2*region_code', 'age**2*gender_Female',
#        'sqrt(age)*region_code', 'age**2*vehicle_damage',
#        'age**2*region_code**3', 'age*Abs(annual_premium)',
#        'age**2*stage_of_life**2', 'region_code**3*exp(age)',
#        'age*policy_sales_channel', 'sqrt(age)*vehicle_damage',
#        'age**3*previously_insured', 'region_code*vehicle_damage',
#        'sqrt(age)*previously_insured', 'annual_premium*vehicle_damage',
#        'region_code**3*vehicle_damage', 'region_code*Abs(annual_premium)',
#        'vehicle_damage*exp(vehicle_age)', 'gender_Female*sqrt(vehicle_age)',
#        'policy_sales_channel*vehicle_age', 'gender_Female*previously_insured',
#        'previously_insured*vehicle_damage',
# ...

# %%
# Applying feature engineer object do X_test

new_X_test = model.transform(X_test)

# %% [markdown]
# ## <font color="gray">6.2 Autofeat as feature selector</font>

# %%
#fsel = FeatureSelector(verbose=1)

#new_X = fsel.fit_transform(pd.DataFrame(X), pd.DataFrame(y_train))
# Out:
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 46 features after 5 feature selection runs
# [featsel] 45 features after correlation filtering
# [featsel] 40 features after noise filtering

# %%
# Saving feature selector object

#pickle.dump(fsel, open('/mnt/d/Gustavo/Rosu/feature_selector_health_insurance.pkl', 'wb'))

# %%
# Loading feature selector object

fsel = pickle.load(open('/mnt/d/Gustavo/Rosu/feature_selector_health_insurance.pkl', 'rb'))

# %%
# Getting selected features

new_X = fsel.transform(pd.DataFrame(X))

# %%
# Redefining new_X indexes

new_X.index = X_train_1.index

# %%
# Getting X_test with selected features

new_X_test = fsel.transform(pd.DataFrame(new_X_test))

# %%
# Redefining new_X_test indexes

new_X_test.index = X_test.index

# %%
new_X
# Out:
#         region_code  stage_of_life  annual_premium  vehicle_damage  \
# id
# 347089     0.673077            0.0       -0.153391             0.0
# 148668     0.192308            0.0       -0.247924             0.0
# 282683     0.538462            2.0        0.635488             1.0
# 101296     0.115385            0.0        0.440577             0.0
# 60279      0.288462            0.0        0.333754             0.0
# ...             ...            ...             ...             ...
# 378817     0.903846            0.0       -0.576696             1.0
# 361829     0.115385            0.0       -0.435727             0.0
# 91745      0.538462            0.0        1.820434             0.0
# 48701      0.153846            1.0       -0.182754             0.0
# 221792     0.288462            0.0       -0.213180             1.0
#
#         driving_license  age*gender_Male  previously_insured  \
# id
# 347089              1.0         0.000000                 1.0
# ...

# %%
new_X_test.head()
# Out:
#         region_code  stage_of_life  annual_premium  vehicle_damage  \
# id
# 372857     0.923077            1.0       -1.930579             0.0
# 329496     0.538462            1.0        0.362121             0.0
# 268198     0.115385            0.0        0.183950             0.0
# 263511     0.538462            0.0       -0.282269             1.0
# 326060     0.750000            0.0        0.015678             0.0
#
#         driving_license  age*gender_Male  previously_insured  \
# id
# 372857              1.0         0.000000                 1.0
# 329496              1.0         0.000000                 1.0
# 268198              1.0         0.030769                 1.0
# 263511              1.0         0.092308                 1.0
# 326060              1.0         0.000000                 1.0
#
#         age*vehicle_age**3  age**2*region_code  age**2*gender_Female  \
# id
# 372857            0.000000            0.237924              0.257751
# ...

# %% [markdown]
# # 7.0 Machine learning

# %% [markdown]
# ## <font color="gray"> 7.1 Baseline model </font>

# %%
model_name = 'Dummy classifier'

model = DummyClassifier(strategy='most_frequent', random_state=42)

df_baseline = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)

df_baseline
# Out:
# Accuracy: 0.877
#
# Balanced Accuracy: 0.5
#
# AUC-ROC: 0.5
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93    110352
#            1       0.00      0.00      0.00     15414
#
#     accuracy                           0.88    125766
#    macro avg       0.44      0.50      0.47    125766
# weighted avg       0.77      0.88      0.82    125766
#          Model name  Accuracy Balanced Accuracy  AUC Precision F1-score Recall
# 0  Dummy classifier  0.877439               0.5  0.5       0.0      0.0    0.0

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_dummy = precision_at_k(X_test, y_test, pred_proba_model, k=2000)

precision_at_k_dummy
# Out:
# 0.107

# %%
# Calculating Recall @ k

recall_at_k_dummy = recall_at_k(X_test, y_test, pred_proba_model, k=2000)

recall_at_k_dummy
# Out:
# 0.013883482548332684

# %% [markdown]
# ## <font color="gray"> 7.2 Logistic Regression </font>

# %%
model_name = 'Logistic Regression balanced'

model = LogisticRegression(random_state=42, 
                           n_jobs=-1, 
                           max_iter=10000,
                          class_weight='balanced')


df_log_reg = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)

df_log_reg
# Out:
# Accuracy: 0.69
#
# Balanced Accuracy: 0.794
#
# AUC-ROC: 0.848
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79    110352
#            1       0.27      0.93      0.42     15414
#
#     accuracy                           0.69    125766
#    macro avg       0.63      0.79      0.61    125766
# weighted avg       0.90      0.69      0.74    125766
#                      Model name  Accuracy Balanced Accuracy       AUC  \
# 0  Logistic Regression balanced  0.690298          0.793547  0.847795
#
#   Precision  F1-score    Recall
# 0  0.274628  0.424072  0.930323

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_lr = precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)

precision_at_k_lr
# Out:
# 0.416

# %%
# Calculating Recall @ k

recall_at_k_lr = recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)

recall_at_k_lr
# Out:
# 0.053976904113143896

# %% [markdown]
# ## <font color="gray"> 7.3 Balanced Random Forest </font>

# %%
model_name = 'Random Forest'

model = BalancedRandomForestClassifier(n_jobs=-1, random_state=42)


df_rf = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)


df_rf
# Out:
# Accuracy: 0.709
#
# Balanced Accuracy: 0.787
#
# AUC-ROC: 0.839
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.68      0.80    110352
#            1       0.28      0.89      0.43     15414
#
#     accuracy                           0.71    125766
#    macro avg       0.63      0.79      0.62    125766
# weighted avg       0.89      0.71      0.76    125766
#       Model name  Accuracy Balanced Accuracy       AUC Precision  F1-score  \
# 0  Random Forest  0.708753          0.787068  0.838509  0.282084  0.428484
#
#      Recall
# 0  0.890814

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_rf = precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)

precision_at_k_rf
# Out:
# 0.3725

# %%
# Calculating Recall @ k

recall_at_k_rf = recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)

recall_at_k_rf
# Out:
# 0.04833268457246659

# %% [markdown]
# ## <font color="gray"> 7.4 XGBoost </font>

# %%
model_name = 'XG Boost'

model = xgb.XGBClassifier(objective='binary:logistic',
                            n_estimators=100,
                            max_depth=10,
                            tree_method='exact',
                            n_jobs=-1,
                            random_state=42, 
                            class_weight='balanced')


df_xgb = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)

df_xgb
# Out:
# Accuracy: 0.877
#
# Balanced Accuracy: 0.507
#
# AUC-ROC: 0.856
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93    110352
#            1       0.47      0.02      0.03     15414
#
#     accuracy                           0.88    125766
#    macro avg       0.67      0.51      0.48    125766
# weighted avg       0.83      0.88      0.82    125766
#   Model name  Accuracy Balanced Accuracy       AUC Precision  F1-score  \
# 0   XG Boost  0.877145          0.507339  0.856015  0.467826  0.033648
#
#      Recall
# 0  0.017452

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_xgb = precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)

precision_at_k_xgb
# Out:
# 0.463

# %%
# Calculating Recall @ k

recall_at_k_xgb = recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)

recall_at_k_xgb
# Out:
# 0.060075256260542366

# %% [markdown]
# ## <font color="gray"> 7.6 LightGBM </font>

# %%
model_name = 'LightGBM'

model = LGBMClassifier(n_jobs=-1, objective='binary', class_weight='balanced')


df_lgbm = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)

df_lgbm
# Out:
# Accuracy: 0.706
#
# Balanced Accuracy: 0.801
#
# AUC-ROC: 0.859
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.68      0.80    110352
#            1       0.29      0.93      0.44     15414
#
#     accuracy                           0.71    125766
#    macro avg       0.63      0.80      0.62    125766
# weighted avg       0.90      0.71      0.76    125766
#   Model name  Accuracy Balanced Accuracy       AUC Precision  F1-score  \
# 0   LightGBM  0.706359          0.800523  0.858677  0.285012  0.435787
#
#      Recall
# 0  0.925263

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_lgbm = precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)

precision_at_k_lgbm
# Out:
# 0.4725

# %%
# Calculating Recall @ k

recall_at_k_lgbm = recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)

recall_at_k_lgbm
# Out:
# 0.06130790190735695

# %% [markdown]
# ## <font color="gray"> 7.7 Extra Trees </font>

# %%
model_name = 'Extra Trees'

model = ExtraTreesClassifier(n_jobs=-1, class_weight='balanced', random_state=42)


df_extra_trees = get_model_metrics(model_name, model, new_X, y_train, new_X_test, y_test)

pred_proba_model = model.predict_proba(new_X_test)

df_extra_trees
# Out:
# Accuracy: 0.834
#
# Balanced Accuracy: 0.591
#
# AUC-ROC: 0.766
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91    110352
#            1       0.30      0.27      0.28     15414
#
#     accuracy                           0.83    125766
#    macro avg       0.60      0.59      0.60    125766
# weighted avg       0.83      0.83      0.83    125766
#     Model name  Accuracy Balanced Accuracy       AUC Precision  F1-score  \
# 0  Extra Trees  0.834136          0.591195  0.765529  0.301964  0.284735
#
#      Recall
# 0  0.269366

# %%
# Confusion matrix

plot_confusion_matrix(model, new_X_test, y_test, normalize='true')

# %%
# Cumulative gain curve

plot_cumulative_gain(y_test,
                     pred_proba_model,
                     figsize=(10,5));

# %%
# Lift curve

plot_lift_curve(y_test,
                pred_proba_model,
                figsize=(10,5));

# %%
# Calculating Precision @ k

precision_at_k_et = precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)

precision_at_k_et
# Out:
# 0.321

# %%
# Calculating Recall @ k

recall_at_k_et = recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)

recall_at_k_et
# Out:
# 0.041650447644998055

# %% [markdown]
# ## <font color="blue"> Summary of metrics </font>

# %%
# General metrics

pd.concat([df_baseline, df_log_reg, df_rf, df_xgb, df_knn, df_lgbm, df_extra_trees])
# Out:
#                      Model name  Accuracy Balanced Accuracy       AUC  \
# 0              Dummy classifier  0.877439               0.5       0.5
# 0  Logistic Regression balanced  0.638503          0.784544  0.798571
# 0                 Random Forest  0.681003          0.791348  0.841626
# 0                      XG Boost  0.877439               0.5   0.84206
# 0                           KNN  0.865775          0.533232  0.790284
# 0                      LightGBM  0.680939          0.791312  0.842025
# 0                   Extra Trees  0.681003          0.791348  0.841711
#
#   Precision  F1-score    Recall
# 0       0.0       0.0       0.0
# 0  0.250415  0.398736  0.978007
# 0  0.269573  0.418742  0.937524
# 0       0.0       0.0       0.0
# 0  0.330405   0.14479  0.092708
# 0  0.269533  0.418694  0.937524
# 0  0.269573  0.418742  0.937524

# %%
# At k metrics

pd.DataFrame({'Precision at k':[precision_at_k_dummy, precision_at_k_lr, precision_at_k_rf, precision_at_k_xgb,
                                precision_at_k_lgbm, precision_at_k_et],
              'Recall at k':[recall_at_k_dummy, recall_at_k_lr, recall_at_k_rf, recall_at_k_xgb,
                             recall_at_k_lgbm, recall_at_k_et]},
             index=['Dummy', 'Logistic Regression', 'Random Forest', 'XG Boost', 'Light GBM', 'Extra Trees'])
# Out:
#                      Precision at k  Recall at k
# Dummy                        0.1070     0.013883
# Logistic Regression          0.4160     0.053977
# Random Forest                0.3725     0.048333
# XG Boost                     0.4630     0.060075
# Light GBM                    0.4725     0.061308
# Extra Trees                  0.3210     0.041650

# %% [markdown]
# ## <font color="blue"> Cross-validation </font>

# %%
# Cross-validation - evaluating models

# Metrics to search
list_metrics_to_search = ['precision_at_k','recall_at_k']


# Models names to evaluate
list_model_names = ['baseline model', 'Logistic Regression', 'Balanced Random Forest', 'XGBoost', 'LightGBM',
                    'Extra trees']


# Models to evaluate
list_models_to_evaluate = [DummyClassifier(strategy='most_frequent', random_state=42),
                           LogisticRegression(random_state=42,
                                              n_jobs=-1,
                                              max_iter=10000,
                                              class_weight='balanced'),
                           BalancedRandomForestClassifier(n_jobs=-1),
                           xgb.XGBClassifier(objective='binary:logistic',
                                             n_estimators=100,
                                             max_depth=10,
                                             tree_method='exact',
                                             n_jobs=-1,
                                             random_state=42, 
                                             class_weight='balanced'),
                           LGBMClassifier(n_jobs=-1,
                                          objective='binary',
                                          class_weight='balanced'),
                           ExtraTreesClassifier(n_jobs=-1, class_weight='balanced')]


# Creating a empty df
df_metrics_cv = pd.DataFrame(columns=list_metrics_to_search, index=list_model_names)


# Selecting the number of folds/splits
n_folds = 5

# Setting the folds (shuffle=True due to imbalance in dataset)
kfold = StratifiedKFold(n_splits=n_folds, random_state=42, shuffle=True)



# Precision at k list do store values
precision_k_list = []

# Recall at k list do store values
recall_k_list = []



print('Starting kfold cross-validation procedures:\n')
    
for it, iterator in zip(list_model_names, list_models_to_evaluate):
    
    # Instantiating the classifier
    model = iterator
    print('\nEvaluating: {}\n'.format(it))
    print('{}\n'.format(iterator))
    
    # loop for metrics evaluation within cross-validation
    for i in list_metrics_to_search:
        
        # fold number counter
        fold_number = 1

        for train_index, test_index in kfold.split(np.array(new_X), np.array(y_train)):

            x_train, x_test = np.array(new_X.reset_index())[train_index], np.array(new_X.reset_index())[test_index]

            Y_train, Y_test = np.array(y_train)[train_index], np.array(y_train)[test_index]

            # Converting splited x_train back to to df
            df_x_train = pd.DataFrame(x_train, columns=new_X.reset_index().columns).set_index('id')

            # Converting splited x_test back to to df
            df_x_test = pd.DataFrame(x_test, columns=new_X.reset_index().columns).set_index('id')

            # Fitting the model
            model.fit(df_x_train, Y_train)

            # Pred proba
            pred_proba_model = model.predict_proba(df_x_test)

            print('Now evaluating: {}, Fold number:{}'.format(i, fold_number))

            fold_number = fold_number + 1

            if i=='precision_at_k':

                # calculate precision at k
                precision_k_result = precision_at_k(df_x_test, Y_test, pred_proba_model, k=2000)

                # add result to list
                precision_k_list.append(precision_k_result)

                #add calculated precision_k_list results to df_metrics_cv
                df_metrics_cv.loc[it,i] = str(round(np.mean(precision_k_list), 2))+' +/-'+str(round(np.std(precision_k_list), 2))           

            else:

                # calculate recall at k
                recall_k_result = recall_at_k(df_x_test, Y_test, pred_proba_model, k=2000)

                # add result to list
                recall_k_list.append(recall_k_result)

                #add calculated precision_k_list results to df_metrics_cv
                df_metrics_cv.loc[it,i] = str(round(np.mean(recall_k_list), 2))+' +/-'+str(round(np.std(recall_k_list), 2))            
    
  
    
print('Metrics calculation fisinhed.\n')


print('Stratified k-fold Cross-validation results:')
df_metrics_cv
# Out:
# Starting kfold cross-validation procedures:
#
#
# Evaluating: baseline model
#
# DummyClassifier(random_state=42, strategy='most_frequent')
#
# Now evaluating: precision_at_k, Fold number:1
# Now evaluating: precision_at_k, Fold number:2
# Now evaluating: precision_at_k, Fold number:3
# Now evaluating: precision_at_k, Fold number:4
# Now evaluating: precision_at_k, Fold number:5
# Now evaluating: recall_at_k, Fold number:1
# Now evaluating: recall_at_k, Fold number:2
# Now evaluating: recall_at_k, Fold number:3
# Now evaluating: recall_at_k, Fold number:4
# Now evaluating: recall_at_k, Fold number:5
#
# Evaluating: Logistic Regression
#
# LogisticRegression(class_weight='balanced', max_iter=10000, n_jobs=-1,
#                    random_state=42)
#
# Now evaluating: precision_at_k, Fold number:1
# Now evaluating: precision_at_k, Fold number:2
# Now evaluating: precision_at_k, Fold number:3
# Now evaluating: precision_at_k, Fold number:4
# Now evaluating: precision_at_k, Fold number:5
# ...

# %% [markdown]
# # 8.0 Hyperparameter fine tuning

# %% [markdown]
# ## <font color="gray"> 8.1 Random search </font>

# %%
# Random search implementation for LightGBM


# parameters to search
parameters = {'boosting_type':['gbdt', 'dart', 'goss', 'dart'],
              'n_estimators':[90, 100, 200],
              'num_leaves':[10, 31, 50, 90],
              'max_depth':[-1, -2, -10],
              'learning_rate':[0.0001, 0.001, 0.1, 1],
              'subsample':[1.0],
              'colsample_bytree':[1.0],
              'min_child_weight':[0.001],
              'min_child_samples':[20]} # choosing the interval values to evaluate


n_iter = 10 # choosing the number o experiments to perform


# cross-validation strategy - fold
kfold = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)


# Implementing Random Search

df_metrics_hp = pd.DataFrame(columns=['Model name',
                                      'iter_number',
                                      'precision_at_k-mean',
                                      'precision_at_k-std'], index=[0]) # creating empty df to fill in

model_name = 'LightGBM' 


iter_count = 1

precision_k_list = []


list_parameters = [] # list to store the parameters used in each n_iter


print('\nStarting Randomized Search CV:\n')

for i in range(n_iter):
    
    hp = {k: random.sample(v,1)[0] for k, v in parameters.items()} # choosing fixed key and random values
    
    print('\nn_iter number: {}\n'.format(iter_count))
    
    print('\nParameters to evaluate in this n_iter:\n')
    
    print(hp)
    
    
    # model instance
    model = LGBMClassifier(boosting_type=hp['boosting_type'],
                           n_estimators=hp['n_estimators'],
                           objective='binary',
                           class_weight='balanced',
                           num_leaves=hp['num_leaves'],
                           max_depth=hp['max_depth'],
                           learning_rate=hp['learning_rate'],
                           subsample=hp['subsample'],
                           colsample_bytree=hp['colsample_bytree'],
                           min_child_weight=hp['min_child_weight'],
                           min_child_samples=hp['min_child_samples'],
                           n_jobs=-1,
                           random_state=42)
    
    print('\nModel instance:\n\n{}\n'.format(model))
    
    
    # CV splits
    
    fold_number = 1
    
    precision_k_list = []

    for train_index, test_index in kfold.split(np.array(new_X), np.array(y_train)):

        x_train, x_test = np.array(new_X.reset_index())[train_index], np.array(new_X.reset_index())[test_index]

        Y_train, Y_test = np.array(y_train)[train_index], np.array(y_train)[test_index]
        
        print('Fold number: {}'.format(fold_number))

        # Converting splited x_train back to to df
        df_x_train = pd.DataFrame(x_train, columns=new_X.reset_index().columns).set_index('id')

        # Converting splited x_test back to to df
        df_x_test = pd.DataFrame(x_test, columns=new_X.reset_index().columns).set_index('id')

        # Fitting the model
        model.fit(df_x_train, Y_train)

        # Pred proba
        pred_proba_model = model.predict_proba(df_x_test)
        
        # calculate precision at k
        precision_k_result = precision_at_k(df_x_test, Y_test, pred_proba_model, k=2000)

        # add result to list
        precision_k_list.append(precision_k_result)
        
        fold_number = fold_number +1
    

    
    
    # filling df
    df_metrics_hp.loc[i,'Model name'] = model_name
    df_metrics_hp.loc[i,'iter_number'] = iter_count
    df_metrics_hp.loc[i,'precision_at_k-mean'] = round(np.mean(precision_k_list), 3)
    df_metrics_hp.loc[i,'precision_at_k-std'] = round(np.std(precision_k_list), 3)
       
       
    
    
    # finishing current n_iter
    print('\nn_iter number {} status: finished\n\n'.format(iter_count))
    
    print('Results of this n_iter:\n\n{}\n\n'.format(df_metrics_hp.loc[i,:]))
    
    print('Summary of results:\n\n{}\n'.format(df_metrics_hp))
    
    print('='*110)
    
    iter_count = iter_count + 1
    
    list_parameters.append(hp)
    
    

print('\nRandomized Search CV status: completed.\n\n')

print('Final results:\n\n{}\n\n'.format(df_metrics_hp))

print('Best parameters:\n\niter_number: {}\n\n{}'.format(df_metrics_hp.sort_values(by='precision_at_k-mean',ascending=False).iloc[0,1],
                                                         list_parameters[df_metrics_hp.sort_values(by='precision_at_k-mean',ascending=False).index[0]]))
# Out:
# Starting Randomized Search CV:
#
#
# n_iter number: 1
#
#
# Parameters to evaluate in this n_iter:
#
# {'boosting_type': 'dart', 'n_estimators': 100, 'num_leaves': 50, 'max_depth': -2, 'learning_rate': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 0.001, 'min_child_samples': 20}
#
# Model instance:
#
# LGBMClassifier(boosting_type='dart', class_weight='balanced', learning_rate=1,
#                max_depth=-2, num_leaves=50, objective='binary',
#                random_state=42)
#
# Fold number: 1
# Fold number: 2
# Fold number: 3
# Fold number: 4
# Fold number: 5
#
# n_iter number 1 status: finished
#
#
# Results of this n_iter:
#
# Model name             LightGBM
# iter_number                   1
# precision_at_k-mean        0.39
# precision_at_k-std        0.017
# Name: 0, dtype: object
#
#
# Summary of results:
#
#   Model name iter_number precision_at_k-mean precision_at_k-std
# 0   LightGBM           1                0.39              0.017
#
# ...
#
# ...

# %% [markdown]
# ## <font color="gray"> 8.2 Tuned final model </font>

# %% [markdown]
# Best parameters:
#
# iter_number: 7
#
# {'boosting_type': 'dart', 'n_estimators': 100, 'num_leaves': 90, 'max_depth': -1, 'learning_rate': 0.1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 0.001, 'min_child_samples': 20}

# %%
# Final best model


# best parameters
parameters = {'boosting_type':'dart',
              'n_estimators': 100,
              'num_leaves': 90,
              'max_depth': -1,
              'learning_rate': 0.1,
              'subsample': 1.0,
              'colsample_bytree': 1.0,
              'min_child_weight': 0.001,
              'min_child_samples': 20}


# model instance
model = LGBMClassifier(boosting_type=parameters['boosting_type'],
                       n_estimators=parameters['n_estimators'],
                       objective='binary',
                       class_weight='balanced',
                       num_leaves=parameters['num_leaves'],
                       max_depth=parameters['max_depth'],
                       learning_rate=parameters['learning_rate'],
                       subsample=parameters['subsample'],
                       colsample_bytree=parameters['colsample_bytree'],
                       min_child_weight=parameters['min_child_weight'],
                       min_child_samples=parameters['min_child_samples'],
                       n_jobs=-1,
                       random_state=42)

# model fit
model.fit(new_X, y_train_1)


# predictions
pred_proba_model = model.predict_proba(new_X_test)


# at k metrics
print('At k final metrics:\n')
print('Precision at k: {}'.format(precision_at_k(new_X_test, y_test, pred_proba_model, k=2000)))
print('Recall at k: {}'.format(recall_at_k(new_X_test, y_test, pred_proba_model, k=2000)))
# Out:
# At k final metrics:
#
# Precision at k: 0.473
# Recall at k: 0.0613727779940314

# %% [markdown]
# # 9.0 Business performance

# %% [markdown]
# ## <font color="gray"> 9.1 Answering business questions </font>

# %% [markdown]
# * Question 1: What percentage of customers interested in purchasing auto insurance will the sales team be able to reach by making 20,000 cals?
#
#
# * Answer: According to Cumulative Gains curve 20,000 calls corresponds to 16% of our customers base (125766 customers total). The curve shows us that is possible to reach 48% of interested customers (7,398 customers). Lift curve shows us that our machine learning model is almost 3 times better than a baseline/random model at reaching interested customers.

# %%
# Number of calls

number_of_calls = 20000

print('Number of calls: {}\n'.format(number_of_calls))


# Number of customers

number_of_customers = y_test.shape[0]

print('Number of customers: {}\n'.format(number_of_customers))


# Percentage of sample

percentage_of_sample = number_of_calls/number_of_customers

print('Percentage of sample: {:.2f}\n'.format(percentage_of_sample))


# Percentage of interested customers

interested_customers = recall_at_k(new_X_test, y_test, pred_proba_model, k=number_of_calls)

print('Percentage of interested customers reached: {:.2f}\n'.format(interested_customers))


# Total of interested customers

print('Total of interested customers in the base: {}\n'.format(len(y_test[y_test==1])))



# Total of interested customers reached

print('Total of interested customers reached by making {} calls: {}\n'.format(number_of_calls, 
                                                                              int(len(y_test[y_test==1])*interested_customers)))


# Ploting cumulative gains curve

plot_cumulative_gain(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3) # vertical dotted line

plt.axhline(y=interested_customers, xmin=0, xmax=1, color='green', linestyle='--', linewidth=3); # horizontal dotted line


# Ploting lift curve

plot_lift_curve(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3); # vertical dotted line
# Out:
# Number of calls: 20000
#
# Number of customers: 125766
#
# Percentage of sample: 0.16
#
# Percentage of interested customers reached: 0.48
#
# Total of interested customers in the base: 15414
#
# Total of interested customers reached by making 20000 calls: 7398

# %% [markdown]
# * Question 2: What if the sales team's capacity increases to 40,000 calls, wha percentage of customers interested in purchasing auto insurance will the sales team be able to contact?
#
#
# * Answer: According to Cumulative Gains curve 40,000 calls corresponds to 32% of our customers base (125766 customers total). The curve shows us that is possible to reach 82% of interested customers (12,647 customers). Lift curve shows us that our machine learning model is almost 2,7 times better than a baseline/random model at reaching interested customers.

# %%
# Number of calls

number_of_calls = 40000

print('Number of calls: {}\n'.format(number_of_calls))


# Number of customers

number_of_customers = y_test.shape[0]

print('Number of customers: {}\n'.format(number_of_customers))


# Percentage of sample

percentage_of_sample = number_of_calls/number_of_customers

print('Percentage of sample: {:.2f}\n'.format(percentage_of_sample))


# Percentage of interested customers

interested_customers = recall_at_k(new_X_test, y_test, pred_proba_model, k=number_of_calls)

print('Percentage of interested customers reached: {:.2f}\n'.format(interested_customers))


# Total of interested customers

print('Total of interested customers in the base: {}\n'.format(len(y_test[y_test==1])))



# Total of interested customers reached

print('Total of interested customers reached by making {} calls: {}\n'.format(number_of_calls, 
                                                                              int(len(y_test[y_test==1])*interested_customers)))


# Ploting cumulative gains curve

plot_cumulative_gain(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3) # vertical dotted line

plt.axhline(y=interested_customers, xmin=0, xmax=1, color='green', linestyle='--', linewidth=3); # horizontal dotted line


# Ploting lift curve

plot_lift_curve(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3); # vertical dotted line
# Out:
# Number of calls: 40000
#
# Number of customers: 125766
#
# Percentage of sample: 0.32
#
# Percentage of interested customers reached: 0.82
#
# Total of interested customers in the base: 15414
#
# Total of interested customers reached by making 40000 calls: 12647

# %% [markdown]
# * Question 3: How many calls does the sales team need to make to reach 80% of the customers interested in purchasing auto insurance?
#
#
# * Answer: 38,480 calls.

# %%
recall_at_k(new_X_test, y_test, pred_proba_model, k=38480)
# Out:
# 0.8000519008693395

# %%
# Number of calls

number_of_calls = 38480

print('Number of calls: {}\n'.format(number_of_calls))


# Number of customers

number_of_customers = y_test.shape[0]

print('Number of customers: {}\n'.format(number_of_customers))


# Percentage of sample

percentage_of_sample = number_of_calls/number_of_customers

print('Percentage of sample: {:.2f}\n'.format(percentage_of_sample))


# Percentage of interested customers

interested_customers = recall_at_k(new_X_test, y_test, pred_proba_model, k=number_of_calls)

print('Percentage of interested customers reached: {:.2f}\n'.format(interested_customers))


# Total of interested customers

print('Total of interested customers in the base: {}\n'.format(len(y_test[y_test==1])))



# Total of interested customers reached

print('Total of interested customers reached by making {} calls: {}\n'.format(number_of_calls, 
                                                                              int(len(y_test[y_test==1])*interested_customers)))


# Ploting cumulative gains curve

plot_cumulative_gain(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3) # vertical dotted line

plt.axhline(y=interested_customers, xmin=0, xmax=1, color='green', linestyle='--', linewidth=3); # horizontal dotted line


# Ploting lift curve

plot_lift_curve(y_test, pred_proba_model, figsize=(15,7))

plt.axvline(x=percentage_of_sample, ymin=0, ymax=1, color='green', linestyle='--', linewidth=3); # vertical dotted line
# Out:
# Number of calls: 38480
#
# Number of customers: 125766
#
# Percentage of sample: 0.31
#
# Percentage of interested customers reached: 0.80
#
# Total of interested customers in the base: 15414
#
# Total of interested customers reached by making 38480 calls: 12332

# %% [markdown]
# # 10.0 Deploy

# %% [markdown]
# ## <font color="gray"> 10.1 Class data_prep.py </font>

# %% [markdown]
# ## <font color="gray"> 10.2 API_handler.py </font>

# %% [markdown]
# ## <font color="gray"> 10.3 API tester local </font>

# %% [markdown]
# ## <font color="gray"> 10.4 API tester remote/cloud </font>
